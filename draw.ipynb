# %%
import csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('test.csv')

ticks = data[data.type == 'tick']
jvm = data[data.type == 'jvm']
potential = data[data.type == 'potential']
plt.figure(figsize=(30, 15))
plt.plot(data['time_point'], data['size'])

# %%
data.head(10)
# Out:
#    time_point  type  size
# 0           1  tick   100
# 1           2  tick     0
# 2           3  tick     0
# 3           4  tick   150
# 4           5  tick     0
# 5           6  tick   100
# 6           7  tick   100
# 7           8  tick     0
